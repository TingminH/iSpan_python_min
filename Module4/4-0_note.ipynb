# %% [markdown]
# |型態| 創建方式 | 可不可變 | 有序/無序 |
# |:---:|:---:|:---:|:---:|
# |list（串列）| [] 或 list()| 可變 (Mutable) |有序 (Ordered) |
# |dict（字典）| {key: value} 或 dict()|可變 (Mutable) |有序 |
# |tuple（元組）|() 或 tuple() | 不可變 (Immutable)|有序 (Ordered) |
# |set（集合）| {} 或 set()|可變 (Mutable) |無序 (Unordered) |
